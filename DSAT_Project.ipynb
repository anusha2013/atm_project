# %%
import random
import sys


class atm():
    def __init__(self,pinnum1 , balance=0):
        self.pin_num=pin_num1
        self.balance = balance

    def deposit(self, amount):
        self.amount = amount
        self.balance = self.balance + self.amount
        print("Current account balance: Num", self.balance)
        print()

    def withdraw(self, amount):
        self.amount = amount
        if self.amount > self.balance:
            print("Insufficient fund!")
            print(f"Your balance is Num{self.balance} only.")
            print("Try with lesser amount than balance.")
            print()
        else:
            self.balance = self.balance - self.amount
            print(f"Num{amount} withdrawal successful!")
            print("Current account balance: Num", self.balance)
            print()

    def transferfunds(self, amount):
        self.amount = amount
        checking_balance = 10000-self.amount

        self.balance = self.balance +self.amount
        print("Account balance: Num", self.balance)
        print()
        print("Checking Balance: Num", checking_balance)
        print()



    def check_balance(self):
        print("Available balance: Num", self.balance)
        print()

    def transaction(self):

        while True:
            try:
                option = int(input("Enter 1, 2, 3, 4 "))
            except:
                print("Error: Enter 1, 2, 3, 4 only!!!\n")
                continue
            else:
                if option == 1:
                    atm.check_balance()
                elif option == 2:
                    amount = int(input("How much you want to deposit(Num):"))
                    atm.deposit(amount)
                elif option == 3:
                    amount = int(input("How much you want to withdraw(Num):"))
                    atm.withdraw(amount)
                elif option == 4:
                    amount = int(input("Enter the amount to transfer(Num):"))
                    atm.transferfunds(amount)
                else:
                    print("Wrong input")
                    sys.exit()
                    




user={'1234':0.0}
print("*******WELCOME TO ATM*******")
print("___________________________________________________________\n")
pin_num1 = input("Enter the pin_num: ")
pin_num2=input("Enter the pin_num again: ")
if pin_num1 != pin_num2:
    print("Wrong pin_num. Try again.")
elif pin_num1 not in user:
    print("Not a registered user")
    x=input("To register enter R else N")
    if x=='R':
        data=input("Enter the pin_num")
        if data in user:
            print("Enter another pin_num")
        else:
            user[data]=0.0
    elif x=='N':
        sys.exit()
    else:
        print("Invalid input")
else:
    print("Pin_num verified")

atm=atm(pin_num1)
while True:
    trans = input("Do you want to do any transaction?(y/n):")
    if trans == "y":
        atm.transaction()
    elif trans == "n":
        print("Thank you")
        break
    else:
        print("Wrong command!\n")
# Out:
# *******WELCOME TO ATM*******
# ___________________________________________________________
#
# Enter the pin_num: 1234
# Enter the pin_num again: 1234
# Pin_num verified
# Do you want to do any transaction?(y/n):y
# Enter 1, 2, 3, 4 1
# Available balance: Num 0
#
# Enter 1, 2, 3, 4 2
# How much you want to deposit(Num):10000
# Current account balance: Num 10000
#
# Enter 1, 2, 3, 4 3
# How much you want to withdraw(Num):199
# Num199 withdrawal successful!
# Current account balance: Num 9801
#
# Enter 1, 2, 3, 4 4
# Enter the amount to transfer(Num):1234
# Account balance: Num 11035
#
# Checking Balance: Num 8766
#
# Enter 1, 2, 3, 4 5
# Wrong input
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# # TABLE OF CONTENTS

# %%
1:User interface
2:Enter pin
3:Main menu
4:Deposit cash
5:Withdraw cash
6:Transfer funds
7:Check balance
8:Balance inquiry
# Out:
#   Cell In [1], line 1
#     1:User interface
#     ^
# SyntaxError: illegal target for annotation

# %% [markdown]
# # DOCUMENTATION

# %%
Introduction
In earlier years, all the transactions were to be done manually. As it is a difficult task, so now banks use ‘Atm’ to give their customers have easy and faster transactions. Thus this project is a good task to have transactions easier, faster and for emergencies.


Scope
• It can be implemented in atm machine by owner of bank or in charge of branch.
• It is easy to learn the task.

Objectives
Our main objective is to speed up the transactions done by the customers. The user can deposit, withdraw or check balance of their account without having to visit the bank.


Development
The project has been made in jupyter notebook using classes and methods.
User has to enter the pin. If the pin gets verified, he can perform transactions in his account.
He has to choose the options as to what he wants to do. He can deposit, withdraw, check balance or transfer the funds.
